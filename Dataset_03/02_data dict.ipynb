# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 96
dir_process_id = 97

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='pantipscrap.json'))
meta
# Out:
# {'owner': 'pranodnard',
#  'human_size': '1.14 MB',
#  'name': 'pantipscrap.json',
#  'description': '-',
#  'directory': 96,
#  'path': 'pranodnard/DSI310-25/raw/pantipscrap.json'}

# %%
data = json.load(fp)
df = data

df = pd.json_normalize(data)
df
# Out:
#                                                 Topic  ComAmount  \
# 0   2021 JYP ESG REPORT | รายงานการพัฒนาองค์กรอย่า...          4
# 1   คุณคิดยังไงกับคำว่า เมื่อก่อนเธอก็เคยลำบาก ทำไ...          0
# 2   ผักออแกนิคในร้านโอ้กะจู๋มีไว้สำหรับจัดจานให้สว...          0
# 3   เรื่องน่ารู้ สารกันบูดในอาหาร อันตรายจริงหรือไม่?          1
# 4   นมขวดแก้วที่ขายในห้างหรู ราคาแพง รสชาติเป็นยัง...          0
# 5                              สามีใจดำกับเราจริงไหม?          0
# 6                        ขอคำปรึกษาด้านอาหารหน่อยครับ          1
# 7           อาหารดีมีประโยชน์ ออแกนิค หน้าตาไม่ชวนกิน          1
# 8   ... ถ้าอยากปลูกผัก Aquaponics ให้เป็นออแกนิค ค...          1
# 9   ทุกคนมีความคิดเห็นยังไงเกี่ยวกับอาหารออแกนิคใน...          0
# 10  [SR] ตะลุยกินถิ่นเชียงราย 9 ร้านอาหารและคาเฟ่ ...         11
# 11  [SR] พาไปกิน Jones Salad อาหารสุขภาพที่มีมากกว...          7
# 12  แม่ๆบ้านไหน ไม่ทำอาหารให้ลูกทานบ้างคะ แบบว่าซื...         17
# ...

# %%
datanode.write(df=df, 
               directory=dir_process_id, 
               name="ข้อมูลชุดที่3_ความเห็นต่ออาหารออแกนิคจาก Pantip", 
               profiling=True, 
               lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='pantipscrap.json')],
               description= "ข้อมูลชุดที่3: ความเห็นที่มีต่ออาหารออแกนิคบนเว็บบอร์ด Pantip ประกอบไปด้วยหัวข้อกระทู้, จำนวนคอมเม้นท์ในกระทู้, คอมเม้นท์ในกระทู้, วันที่ตั้งกระทู้, เวลาที่ตั้งกระทู้, URL ที่มาของกระทู้ ซึ่งเก็บข้อมูลเมื่อวันที่ 2/11/2022")
# Out:
# {'sucess': True,
#  'file_id': 489,
#  'path': 'pranodnard/DSI310-25/process/ข้อมูลชุดที่3_ความเห็นต่ออาหารออแกนิคจาก Pantip.parquet',
#  'lineage': True}
