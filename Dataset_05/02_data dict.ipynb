# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 96
dir_process_id = 97

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='wongnai.json'))
meta
# Out:
# {'owner': 'pranodnard',
#  'human_size': '62.09 KB',
#  'name': 'wongnai.json',
#  'description': 'file wongnai.json',
#  'directory': 96,
#  'path': 'pranodnard/DSI310-25/rawData/wongnai.json'}

# %%
data = json.load(fp)
df = data

df = pd.json_normalize(data)
df
# Out:
#                                                  Name PriceRange  \
# 0                  ORGANIC SUPPLY (ออร์แกนิค ซัพพลาย)    101-250
# 1   Salada Organic Kitchen (ซาลาด้า ออร์แกนิค คิทเ...    101-250
# 2                               ชาบูบ้านผัก ออร์แกนิค    101-250
# 3   Salada Organic Kitchen (ซาลาด้า ออร์แกนิค คิทเ...    101-250
# 4   สวงอยู่ที่วังหลัง ออร์แกนิคคาเฟ่ (Sawong at Wa...    101-250
# ..                                                ...        ...
# 95  กอบัวฟาร์ม โฮมเมด ออร์แกนิคฟู้ดส์ (กอบัวฟาร์ม ...       <100
# 96                          ตามใจคาเฟ่ (Taamjai Cafe)    101-250
# 97                                    สวนผัก โอ้กะจู๋    251-500
# 98                  เชฟขนมถ้วย ออร์แกนิค (เชฟขนมถ้วย)       <100
# 99                                ไร่ออนซอน ออร์แกนิค       <100
#
#                                  Categories           Time     Telephone  \
# 0              อาหารมังสวิรัติ,เบเกอรี/เค้ก  09:00 - 19:00     020707996
# ...

# %%
datanode.write(df=df, 
               directory=dir_process_id, 
               name="ข้อมูลชุดที่5_รายการร้านค้าที่ขายอาหาร Organic ในกรุงเทพฯ", 
               profiling=True, 
               lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='pantipscrap.json')],
               description= "ข้อมูลชุดที่5: รายการร้านค้าที่ขายอาหาร Organic ในกรุงเทพฯ บน Wongnai ประกอบไปด้วยชื่อร้านอาหาร, ช่วงราคาของอาหาร, ประเภทอาหาร, ช่วงเวลาการเปิด-ปิด, เบอร์โทรติดต่อ, รีวิว, สถานที่ตั้ง, และเรทติ้ง ซึ่งเก็บข้อมูลเมื่อวันที่ 9/11/2022 เพื่อนำไปวิเคราะห์ช่วงราคาร้านอาหาร Organic ประเภทอาหารที่ได้รับความนิยม ความเห็นของผู้บริโภค และสามารถนำไปปรับใช้กับการออกแบบ Business Model ให้กับผู้ประกอบการร้านอาหาร Organic ได้อย่างเหมาะสม โดยกระบวนการรวบรวมข้อมูลคือการ scrape จากเว็บไซต์ https://www.wongnai.com/")
# Out:
# {'sucess': True,
#  'file_id': 671,
#  'path': 'pranodnard/DSI310-25/processData/ข้อมูลชุดที่5_รายการร้านค้าที่ขายอาหาร Organic ในกรุงเทพฯ.parquet',
#  'lineage': True}
