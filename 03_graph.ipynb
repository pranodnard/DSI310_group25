# %% [markdown]
# # 03_graph
# - process news SPO analytics via graph algorithm

# %% [markdown]
# ### install extra library

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (2.8.5)

# %% [markdown]
# ### read news SPO from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
from tqdm.auto import tqdm

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
dir_process_id = 97

# %%
df = datanode.read_df(datanode.get_file_id(directory_id=dir_process_id, name="spo.parquet"))
df
# Out:
#                                            Product_Name Product_Price  \
# 0     ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็...            10
# 1     ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็...            10
# 2     ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็...            10
# 3     ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็...            10
# 4     ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็...            10
# ...                                                 ...           ...
# 9809           ดีน่าโทนิวน้ำเต้าหู้ออร์แกนิค 180มล.แพค4            UH
# 9810           ดีน่าโทนิวน้ำเต้าหู้ออร์แกนิค 180มล.แพค4            UH
# 9811           ดีน่าโทนิวน้ำเต้าหู้ออร์แกนิค 180มล.แพค4            UH
# 9812           ดีน่าโทนิวน้ำเต้าหู้ออร์แกนิค 180มล.แพค4            UH
# 9813           ดีน่าโทนิวน้ำเต้าหู้ออร์แกนิค 180มล.แพค4            UH
#
#      Product_Unit Product_Category
# 0            ชิ้น        100%Juice
# 1            ชิ้น        100%Juice
# 2            ชิ้น        100%Juice
# 3            ชิ้น        100%Juice
# 4            ชิ้น        100%Juice
# ...           ...              ...
# 9809          แพค     UHTDairyFree
# 9810          แพค     UHTDairyFree
# 9811          แพค     UHTDairyFree
# 9812          แพค     UHTDairyFree
# 9813          แพค     UHTDairyFree
#
# [9814 rows x 4 columns]

# %% [markdown]
# ### prepair graph data

# %%
graph_data = [(elm.get('Product_Name'), elm.get('Product_Category')) for elm in df.to_dict('records')]
graph_data
# Out:
# [('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.', '100%Juice'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('แพร์คอเรลลา', 'Apples&Pears'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม',
#   'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม', 'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม',
#   'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
#  ('เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม', 'BabyFood'),
# ...
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม',
#   'BabyFood'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('คาร์ฟูร์บิสกิตรสเนย 167กรัม', 'Biscuit&Cookies'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('สังข์หยดข้าวกล้องอินทรีย์ 1กก.', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ('หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.', 'BrownRice'),
#  ...]

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

from bokeh.io import output_notebook, show, save
from bokeh.models import Range1d, Circle, ColumnDataSource, MultiLine
from bokeh.plotting import figure
from bokeh.plotting import from_networkx

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
'''
use for clear bokeh plot
'''
# from bokeh.io import curdoc
# curdoc().clear()
# Out:
# '\nuse for clear bokeh plot\n'

# %%
news_titles = {elm:'Category' for elm in list(df['Product_Category'].unique())}
news_titles
# Out:
# {'100%Juice': 'Category',
#  'Apples&Pears': 'Category',
#  'BabyFood': 'Category',
#  'Biscuit&Cookies': 'Category',
#  'BrownRice': 'Category',
#  'Cereal': 'Category',
#  'CheeseSpread&Snack': 'Category',
#  'ChiaSeeds&FlaxSeed': 'Category',
#  'Chocolate': 'Category',
#  'CocoaPowder': 'Category',
#  'CoconutMilk': 'Category',
#  'CoconutOil': 'Category',
#  'CoffeeSugar': 'Category',
#  'CookingSugar': 'Category',
#  'CookingVinegar': 'Category',
#  'Crackers': 'Category',
#  'DriedBeansNuts&Seeds': 'Category',
#  'DriedSoupIngredients': 'Category',
#  'DrinkingYogurt': 'Category',
#  'FlavoredMilk': 'Category',
#  'FlavoredUHTMilk': 'Category',
#  'FlavoredYogurt': 'Category',
#  'Flour': 'Category',
#  'FreshEggs': 'Category',
#  'FreshVegetables': 'Category',
#  'FrozenMeals': 'Category',
#  'FrozenVegetables': 'Category',
#  'HerbalTea': 'Category',
#  'Honey&Syrup': 'Category',
#  'InstantPorridge&RiceSoup': 'Category',
#  'InstantSoup&Mixed': 'Category',
#  'Jams&Marmalade': 'Category',
#  'JasmineRice': 'Category',
#  'Ketchup&TomatoPaste': 'Category',
#  'MSGBouillonCube&Powder': 'Category',
#  'Mayonnaise': 'Category',
#  'Mom&Kids': 'Category',
#  'Muesli&Granola': 'Category',
#  'Mushroom': 'Category',
#  'Nuts&SeedSnacks': 'Category',
#  'OatMeal': 'Category',
#  'OliveOil': 'Category',
#  'Orange&Pomelo': 'Category',
#  'OrganicRice': 'Category',
#  'Palm&SpecialtySugar': 'Category',
#  'Pantry&Ingredients': 'Category',
#  'Pasta&Spaghetti': 'Category',
#  'PeanutButter': 'Category',
#  'PlainMilk': 'Category',
#  'PlainYogurt': 'Category',
#  'PotatoChips': 'Category',
#  'Roast&GroundCoffee': 'Category',
#  'Salt,Pepper&ChilliPowder': 'Category',
#  'Seasoning&DippingSauce': 'Category',
#  'Soup&Stock': 'Category',
#  'Soy&CerealBeverages': 'Category',
#  'SpaghettiSauce': 'Category',
#  'SpecialtyOils': 'Category',
#  'SpecialtyRice': 'Category',
#  'Spices': 'Category',
#  'TeaBag': 'Category',
#  'TeaLeaves': 'Category',
#  'Toppings&Others': 'Category',
#  'UHTDairyFree': 'Category'}

# %%
node_colors = {elm:'skyblue' if elm in news_titles else 'yellow' for elm in G.nodes()}
node_colors
# Out:
# {'ซันบลาสน้ำแอปเปิ้ลเชอร์รี่ออร์แกนิก100เปอร์เซ็นต์ 200มล.': 'yellow',
#  '100%Juice': 'skyblue',
#  'ซันบลาสน้ำแอปเปิ้ลผสมมะม่วงออร์แกนิก100เปอร์เซ็นต์ 200มล.': 'yellow',
#  'แพร์คอเรลลา': 'yellow',
#  'Apples&Pears': 'skyblue',
#  'เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสฟักทองผสมแครอท 40กรัม': 'yellow',
#  'BabyFood': 'skyblue',
#  'โดโซะเบบี้ไบท์ข้าวหอมญี่ปุ่นอบกรอบออร์แกนิครสแครอท 24ชิ้น 50กรัม': 'yellow',
#  'แอปเปิ้ลมังกี้ข้าวอบกรอบรสฟักทอง 30กรัม': 'yellow',
#  'ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมผักโขมและแครอท 80กรัม': 'yellow',
#  'โอนลี่ออแกนิคกล้วย บลูเบอร์รี & ควินัวอาหารเสริมสำหรับเด็ก 120กรัม': 'yellow',
#  'ซองเดอร์เบบี้โจ๊กข้าวกล้องงอกออร์แกนิคผสมข้าวโพดหวานและแครอท 80กรัม': 'yellow',
#  'อังเคิลมาร์คออแกนิคข้าวกล้องงอกอบกรอบผสมบีทรูทและมันเทศ 40กรัม': 'yellow',
#  'เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสผักรวม 40กรัม': 'yellow',
#  'แอปเปิ้ลมังกี้ข้าวอบกรอบรสมันหวาน 30กรัม': 'yellow',
#  'เบบี้เนเชอร่าข้าวไรซ์เบอร์รี่ออร์แกนิกอบกรอบรสแอปเปิ้ลผสมเบอร์รี่ 40กรัม': 'yellow',
#  'โอนลี่ออแกนิคแอปเปิล กล้วย & มะม่วงอาหารเสริมสำหรับทารก 120กรัม': 'yellow',
#  'คาร์ฟูร์บิสกิตรสเนย 167กรัม': 'yellow',
#  'Biscuit&Cookies': 'skyblue',
#  'สยามปราณาข้าวกล้องดอยออร์แกนิคพันธุ์บือเนอมูซากอ 1กก.': 'yellow',
#  'BrownRice': 'skyblue',
#  'กรีนเนทข้าวหอมมะลิสามกล้องอินทรีย์ 1กก.': 'yellow',
#  'สังข์หยดข้าวกล้องอินทรีย์ 1กก.': 'yellow',
#  'กรีนเนทปลายข้าวสามกล้องอินทรีย์ 500กรัม': 'yellow',
#  'หงษ์ทองข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.': 'yellow',
#  'มายช้อยส์ข้าวกล้องหอมมะลิอินทรีย์ 1กก.': 'yellow',
#  'มายช้อยส์ข้าวไรซ์เบอร์รี่ออร์แกนิค 1กก.': 'yellow',
#  'มายช้อยส์ข้าวกล้อง 3 สีอินทรีย์ 1กก.': 'yellow',
#  'ไทไทข้าวกล้องหอมนิลอินทรีย์ 1กก.': 'yellow',
#  'เนเชอเรลข้าวไรซ์เบอร์รี่อินทรีย์ 1กก.': 'yellow',
#  'กรีนเนทข้าวหอมมะลิแดงอินทรีย์ 1กก.': 'yellow',
#  'ฮักปันข้าวกล้องไรซ์เบอร์รี่อินทรีย์ 1กก.': 'yellow',
#  'มายช้อยส์ข้าวกล้องหอมแดงอินทรีย์ 1กก.': 'yellow',
#  'ไทไทข้าวกล้องสามสีอินทรีย์ 2กก.': 'yellow',
#  'เนเจอร์พาร์ทอาหารเช้าธัญพืชโฮลเกรนอบกรอบ 375กรัม': 'yellow',
#  'Cereal': 'skyblue',
#  'แฟมิเลียธัญพืชอบกรอบรสช็อกโกแลตผสมเฮเซลนัต 375กรัม': 'yellow',
#  'โพสท์ข้าวสาลีชนิดชิ้นฝอย 464กรัม': 'yellow',
#  'แฟมิเลียธัญพืชอบกรอบผสมน้ำผึ้งและอัลมอนด์ 375กรัม': 'yellow',
#  'เลอพัคสเปรดเดเบิลออร์กานิครสเค็มน้อย 200กรัม': 'yellow',
#  'CheeseSpread&Snack': 'skyblue',
#  'มายช้อยส์ถั่ว5สีออร์แกนิค 200กรัม': 'yellow',
#  'ChiaSeeds&FlaxSeed': 'skyblue',
#  'เนธารี่เมล็ดเซียสีด 450กรัม': 'yellow',
#  'บ๊อบส์เรดมิลล์เมล็ดข้าวฟ่างกลูเตนฟรี 794กรัม': 'yellow',
#  'มายช้อยส์เมล็ดเฟลกซ์สีทองออร์แกนิค 200กรัม': 'yellow',
#  'อัลเซเนโรเรียลควินัวออร์แกนิค 400กรัม': 'yellow',
#  'มายช้อยส์ข้าวฟ่างออร์แกนิค 200กรัม': 'yellow',
#  'สไวเซอร์เชียซีด 200กรัม': 'yellow',
#  'มายช้อยส์เมล็ดควินัว3สีออร์แกนิค 200กรัม': 'yellow',
#  'บอดี้เชพควินัวขาว 320กรัม': 'yellow',
#  'บ๊อบส์เรดมิลล์ออร์แกนิคบราวน์เฟล็กซีดส์ 368กรัม': 'yellow',
#  'นูทรีริสควินัวสามสี 350กรัม': 'yellow',
#  'คาร์ฟูร์ช็อกโกแลตคาคาว52เปอร์เซ็นต์ 200กรัม': 'yellow',
#  'Chocolate': 'skyblue',
#  'คาร์ฟูร์ช็อกโกแลต74เปอร์เซ็นต์คาคาว 100กรัม': 'yellow',
#  'นูทริริสคาเคาพาวเดอร์ออร์แกนิค 250กรัม': 'yellow',
#  'CocoaPowder': 'skyblue',
#  'อะยัมกะทิผสมน้ำมะพร้าวสูตรไขมันน้อยกว่า 250มล.': 'yellow',
#  'CoconutMilk': 'skyblue',
#  'เมอริโต้กะทิอินทรีย์ 400มล.': 'yellow',
#  'อะยัมกะทิออร์แกนิคผสมน้ำมะพร้าว 250มล.': 'yellow',
#  'เนเชอเรลฟอร์เต้น้ำมันมะพร้าวสกัดเย็น 500มล.': 'yellow',
#  'CoconutOil': 'skyblue',
#  'อะกรีไลฟ์น้ำมันมะพร้าวออร์แกนิค 450มล.': 'yellow',
#  'อะกรีไลฟ์น้ำตาลดอกมะพร้าวออร์แกนิค 230กรัม': 'yellow',
#  'CoffeeSugar': 'skyblue',
#  'วังขนายน้ำตาลทรายแดงออร์แกนิค 500กรัม': 'yellow',
#  'CookingSugar': 'skyblue',
#  'แฮปปี้เมทน้ำส้มสายชูหมักแอปเปิ้ลออร์แกนิค 500มล.': 'yellow',
#  'CookingVinegar': 'skyblue',
#  'แบรคน้ำส้มสายชูหมักจากแอปเปิ้ล 946มล.': 'yellow',
#  'อัลเซเนโรน้ำส้มสายชูออร์แกนิคหมักจากองุ่น 250 มล.': 'yellow',
#  'แอนเดรียมิลาโนน้ำส้มสายชูหมักบัลซามิกออร์แกนิค 500มล.': 'yellow',
#  'แอนเดรียมิลาโนน้ำส้มสายชูหมักจากแอปเปิ้ลผสมอบเชยและขมิ้น 500มล.': 'yellow',
#  'ดีนิกรีสน้ำส้มสายชูหมักจากแอปเปิ้ลออแกนิก 500มล.': 'yellow',
#  'บรูคน้ำส้มสายชูหมักจากแอปเปิ้ลออร์แกนิค 473มล.': 'yellow',
#  'แอนเดรียมิลาโนน้ำส้มสายชูหมักจากแอปเปิ้ล 500มล.': 'yellow',
#  'โซลาน่าโกลด์น้ำส้มสายชูหมักจากแอปเปิ้ลออร์แกนิค 470มล.': 'yellow',
#  'ไฮนซ์น้ำส้มสายชูหมักจากแอปเปิ้ลออร์แกนิคไม่ผ่านการกรอง 946มล.': 'yellow',
#  'บรูคน้ำส้มสายชูหมักจากแอปเปิ้ลออร์แกนิค 946มล.': 'yellow',
#  'สเปกตรัมน้ำส้มสายชูออร์แกนิกหมักแอปเปิ้ล 473มล.': 'yellow',
#  'คารันดินีออร์แกนิคน้ำส้มสายชูหมักจากแอปเปิ้ล 500มล.': 'yellow',
#  'อัลเซเนโรน้ำส้มสายชูหมักจากแอปเปิ้ลออร์แกนิคชนิดผ่านการกรอง 500มล.': 'yellow',
#  'ออร์เทลลีอะชิโตน้ำส้มสายชูบัลซามิคเวเนการ์ออฟโมเดน่าออร์แกนิค 250มล.': 'yellow',
#  'อัลเซเนโร่บัลซามิคเกลซออฟโมเดน่าอะซีโตบัลซามิโคไอจีพีออร์แกนิค 150มล.': 'yellow',
#  'แบรคน้ำส้มสายชูหมักจากแอปเปิ้ล 473มล.': 'yellow',
#  'แอนเดรียมิลาโนน้ำส้มสายชูหมักจากไวน์ขาวออร์แกนิค 500มล.': 'yellow',
#  'อะกรีไลฟ์น้ำส้มสายชูหมักจากน้ำกะทิไขมันต่ำ 480มล.': 'yellow',
#  'ออไรท์ธัญพืชออแกนิคอบกรอบธัญพืช5ชนิด 76กรัม': 'yellow',
#  'Crackers': 'skyblue',
#  'ออไรท์ธัญพืชออแกนิคอบกรอบชนิดธัญพืช3ชนิด 76กรัม': 'yellow',
#  'เวทโทรสถั่วเลนทิลส์เขียว 500กรัม': 'yellow',
#  'DriedBeansNuts&Seeds': 'skyblue',
#  'วทโทรสถั่วเลนทิลส์แดง 500กรัม': 'yellow',
#  'นูทรีริสเก๋ากี้ออร์แกนิค 180กรัม': 'yellow',
#  'DriedSoupIngredients': 'skyblue',
#  'แดรี่โฮมโยเกิร์ตพร่องมันเนย 100มล.': 'yellow',
#  'DrinkingYogurt': 'skyblue',
#  'แดรี่โฮมนมสดรสบัตเตอร์สก็อตซ์ 200ซีซี': 'yellow',
#  'FlavoredMilk': 'skyblue',
#  'เพียวฮาร์เวสต์ออสซี่ดรีมน้ำนมข้าวโอ๊ตออร์แกนิค 1ลิตร': 'yellow',
#  'FlavoredUHTMilk': 'skyblue',
#  'ลิฟวิ่งเพลนเน็ดออร์เกนิคนมยูเอชทีเข้มข้น 1ลิตร': 'yellow',
#  'แดรี่โฮมกรีกโยเกิร์ต 140กรัม': 'yellow',
#  'FlavoredYogurt': 'skyblue',
#  'บัตเตอร์ฟลายโยเกิร์ตผสมเซียซีด  100กรัม': 'yellow',
#  'บัตเตอร์ฟลายโยเกิร์ตชนิดคงตัวผสมโกจิเบอร์รี่ 100กรัม': 'yellow',
#  'บ๊อบเรดมิลล์แป้งเมล็ดอัลมอนด์ 453กรัม': 'yellow',
#  'Flour': 'skyblue',
#  'บ๊อบส์เรดมิลล์ออร์แกนิคสเปลท์ฟลาวร์ 567กรัม': 'yellow',
#  'เวทโทรสดัชชี่ออร์แกนิคเพลนแป้งสาลี 1.5กก.': 'yellow',
#  'บ๊อบเรดมิลล์อันบลีซด์ไวท์ออลเพอร์โพสออแกนิคฟลาวร์ 2270กรัม': 'yellow',
#  'เวทโทรสดัชชี่ออร์แกนิคสตรองไวท์แป้งสำเร็จรูปสำหรับทำขนมปัง 1.5กก.': 'yellow',
#  'บ๊อบส์เรดมิลล์ออแกนิคเซเว่นเกรนแพนเค้กแอนด์วาฟเฟิลโฮลเกรนมิกซ์ 680กรัม': 'yellow',
#  'บ๊อบส์เรดมิลล์ออร์แกนิคโฮลเกรนดาร์กไรย์ฟลาวร์ 567กรัม': 'yellow',
#  'เวทโทรสดัชชี่ออร์แกนิคสโตนกราวด์โฮลมีลแป้งสาลี 1.5กก.': 'yellow',
#  'มายช้อยส์ไข่ไก่สดออร์แกนิคแพค 10ฟอง': 'yellow',
#  'FreshEggs': 'skyblue',
#  'ฮิลไทรบ์ไข่ไก่ออร์แกนิคขนาดใหญ่แพค 6ฟอง': 'yellow',
#  'ฮิลไทรบ์ไข่ไก่ออร์แกนิคแพค 10ฟอง': 'yellow',
#  'ดร.ผักกาดขาวปลีออร์แกนิค 400กรัม(C': 'yellow',
#  'FreshVegetables': 'skyblue',
#  'มายช้อยส์เห็ดหูหนูดำออร์แกนิค 100กรัม': 'yellow',
#  'บีทรูทออร์แกนิค': 'yellow',
#  'ดร.กะหล่ำปลีออร์แกนิค 600กรัม(C': 'yellow',
#  'มายช้อยส์เห็ดนางรมดอยออร์แกนิค 100กรัม': 'yellow',
#  'มายช้อยส์ขมิ้นเหลืองออร์แกนิค 100กรัม': 'yellow',
#  'มายช้อยส์วอเตอร์เครสออร์แกนิค 100กรัม': 'yellow',
#  'มายช้อยส์เห็ดโคนญี่ปุ่นออร์แกนิค 150กรัม': 'yellow',
#  'เพื่อนพึ่งภามันเทศพันธุ์ญี่ปุ่น 500กรัม': 'yellow',
#  'มายช้อยส์เห็ดรวมออร์แกนิค 200กรัม': 'yellow',
#  'ดับบิวบีมะระจีนออร์แกนิค(C': 'yellow',
#  'มายช้อยส์ข้าวโพดอ่อนออร์แกนิค 150กรัม': 'yellow',
#  'มายช้อยส์เห็ดเข็มทองออร์แกนิค 200กรัม': 'yellow',
#  'มายช้อยส์กะหล่ำปลีออร์แกนิค': 'yellow',
#  'มายช้อยส์มะเขือพวงออร์แกนิค 100กรัม': 'yellow',
#  'มายช้อยส์ผักกาดขาวออร์แกนิค 400กรัม': 'yellow',
#  'มายช้อยส์กวางตุ้งใบ 200กรัม': 'yellow',
#  'ซุปเปอร์เฟรชสปริงมิกซ์ออร์แกนิค 80กรัม': 'yellow',
#  'มายช้อยส์ต้นหอมญี่ปุ่นออร์แกนิค 350กรัม': 'yellow',
#  'มายช้อยส์เห็ดยามาบูชิตาเกะออร์แกนิค 100กรัม': 'yellow',
#  'มายช้อยส์ข้าวโพดหวานออร์แกนิค แพค 2': 'yellow',
#  'มายช้อยส์เห็ดนางรมหลวงออร์แกนิค 200กรัม': 'yellow',
#  'มายช้อยส์มะนาวออร์แกนิค แพค4': 'yellow',
#  'ดร.ฟักทองออร์แกนิค 350กรัม(C': 'yellow',
#  'กาลเวลาต้นอ่อนทานตะวัน 100กรัม': 'yellow',
#  'มายช้อยส์ฟักทองอินทรีย์': 'yellow',
#  'ดับบิวบีกวางตุ้งฮ่องเต้ออร์แกนิค 180กรัม(C': 'yellow',
#  'มายช้อยส์ตะไคร้ออร์แกนิค 200กรัม': 'yellow',
#  'เอมี่ส์ชุดอาหารแผ่นแป้งข้าวโพดห่อชีส&ถั่วดำ&มะเขือเทศออร์แกนิก 255กรัม': 'yellow',
#  'FrozenMeals': 'skyblue',
#  'เวทโทรสใบผักโขมปลอดสาร 500กรัม': 'yellow',
#  'FrozenVegetables': 'skyblue',
#  'เวทโทรสผักรวมผสมบลอคโครี่ปลอดสาร 750กรัม': 'yellow',
#  'มายช้อยส์ใบชาเขียวออร์แกนิค 100กรัม': 'yellow',
#  'HerbalTea': 'skyblue',
#  'เรนองทีชาสมุนไพรตะไคร้ใบเตยออร์แกนิค 1กรัม แพค 20ซอง': 'yellow',
#  'เนเจอร์กรีนชาตะไคร้ออร์แกนิค 1กรัม แพค 30ซอง': 'yellow',
#  'เนเจอร์กรีนชาใบเตยออร์แกนิค 1กรัม แพค 30ซอง': 'yellow',
#  'คาร์ฟูร์มิเอลเดอเฟอร์เครเมอเอสซิมเมอวิเยน้ำผึ้ง 500กรัม': 'yellow',
#  'Honey&Syrup': 'skyblue',
#  'คลาคน้ำเชื่อมออแกนนิคอากาเว้ไซรัป 250มล.': 'yellow',
#  'ซองเดอร์โจ๊กข้าวกล้องงอกออร์แกนิครสเห็ดหอม 30กรัม': 'yellow',
#  'InstantPorridge&RiceSoup': 'skyblue',
#  'ซองเดอร์โจ๊กข้าวกล้องงอกออร์แกนิครสเห็ดหอม 30กรัม แพค 3': 'yellow',
#  'ซองเดอร์โจ๊กข้าวกล้องผสมสาหร่าย 30กรัม': 'yellow',
#  'มาสเซิ่ลออแกนิคซุปรสไก่กึ่งสำเร็จรูป 1ลิตร': 'yellow',
#  'InstantSoup&Mixed': 'skyblue',
#  'คาร์ฟูร์แยมราสพ์เบอร์รี่ 360กรัม': 'yellow',
#  'Jams&Marmalade': 'skyblue',
#  'คาร์ฟูร์แยมบลูเบอร์รี่ 360กรัม': 'yellow',
#  'คาร์ฟูร์แยมสตรอเบอร์รี่ 360กรัม': 'yellow',
#  'คาร์ฟูร์มิเอลเดอเฟอร์ลิควิคโวอิกาน้ำผึ้ง 500กรัม': 'yellow',
#  'ธรรมข้าวหอมมะลิ 5กษัตริย์ออแกนิค 475กรัม': 'yellow',
#  'JasmineRice': 'skyblue',
#  'มายช้อยส์ข้าวหอมมะลิอินทรีย์ 1กก.': 'yellow',
#  'มายช้อยส์ไทยข้าวหอมมะลิอินทรีย์ 1กก.': 'yellow',
#  'ไทไทข้าวขาวหอมมะลิอินทรีย์ 2กก.': 'yellow',
#  'ธรรมข้าวหอมมะลิล้านนาออแกนิค 475กรัม': 'yellow',
#  'ฮักปันข้าวหอมมะลิอินทรีย์ 1กก.': 'yellow',
#  'ไฮนซ์ซอสมะเขือเทศออร์แกนิคขวดพลาสติก 397กรัม': 'yellow',
#  'Ketchup&TomatoPaste': 'skyblue',
#  'อัลเซเนโรซุปผักกึ่งสำเร็จรูปชนิดก้อนออร์แกนิค 100กรัม': 'yellow',
#  'MSGBouillonCube&Powder': 'skyblue',
#  'เวทโทรสเอสเซนเชี่ยลมายองเนสไขมันต่ำ 450มล.': 'yellow',
#  'Mayonnaise': 'skyblue',
#  'แอปเปิ้ลมังกี้ข้าวอบกรอบรสข้าวโพด 30กรัม': 'yellow',
#  'Mom&Kids': 'skyblue',
#  'เนเจอร์สพาร์ทเมล็ดฟักทองธัญพืช 325กรัม': 'yellow',
#  'Muesli&Granola': 'skyblue',
#  'มายช้อยส์เห็ดญี่ปุ่นคอมโบ 150กรัม': 'yellow',
#  'Mushroom': 'skyblue',
#  'มายช้อยส์เห็ดหิมะ 100กรัม': 'yellow',
#  'มายช้อยส์เห็ดชิเมจิ 120กรัม': 'yellow',
#  'อิจิโร่เกาลัดคั่วกระเทาะเปลือก 100กรัม': 'yellow',
#  'Nuts&SeedSnacks': 'skyblue',
#  'ทองการ์เด้นเกาลัดแกะเปลือก 120กรัม': 'yellow',
#  'เวทโทรสอาหารเช้าธัญพืชจัมโบ้โอ๊ต 1กก.': 'yellow',
#  'OatMeal': 'skyblue',
#  'ฟลาฮาวานไอริชควิกข้าวโอ๊ต 500กรัม': 'yellow',
#  'มายช้อยส์น้ำมันมะกอกออร์แกนิคเอ็กซ์ตร้าเวอร์จิ้นกลิ่นเห็ดทรัฟเฟิล 250มล.': 'yellow',
#  'OliveOil': 'skyblue',
#  'เบอร์ทอลลี่น้ำมันมะกอกออร์แกนิคเอ็กซ์ตร้าเวอร์จิ้น 500มล.': 'yellow',
#  'เบอร์ทอลลีสเปรย์น้ำมันมะกอกเอ็กซ์ตร้าเวอร์จิ้นออร์แกนิค 132กรัม': 'yellow',
#  'โมนีนี่น้ำมันมะกอกเอ็กซ์ตร้าเวอร์จิ้นออร์กานิค 500มล.': 'yellow',
#  'เบอร์ทอลลี่น้ำมันมะกอกออร์แกนิคเอ็กซ์ตร้าเวอร์จิ้น 1ลิตร': 'yellow',
#  'มายช้อยส์น้ำมันมะกอกออร์แกนิคเอ็กซ์ตร้าเวอร์จิ้น 250มล.': 'yellow',
#  'โมนีนี่น้ำมันมะกอกคลาสสิโคเอ็กซ์ตร้าเวอร์จิ้น 500มล.': 'yellow',
#  'มายช้อยส์ส้มโอขาวแตงกวา': 'yellow',
#  'Orange&Pomelo': 'skyblue',
#  'มาบุญครองข้าวหอมมะลิอินทรีย์ 1กก.': 'yellow',
#  'OrganicRice': 'skyblue',
#  'เนเชอเรลข้าวกล้องหอมมะลิอินทรีย์ 1กก.': 'yellow',
#  'แฟร์ดีข้าวกล้องหอมมะลิผสมควินัวออร์แกนิค 500กรัม': 'yellow',
#  'วังขนายน้ำตาลออร์แกนิค 1กก.': 'yellow',
#  'Palm&SpecialtySugar': 'skyblue',
#  'บ๊อบส์เรดมิลล์น้ำตาลมะพร้าวออร์แกนิค 369กรัม': 'yellow',
#  'แบรคน้ำสลัดสูตรไม่ใส่น้ำมันผสมน้ำส้มสายชูแอปเปิ้ลไซเดอร์ 354มล.': 'yellow',
#  'Pantry&Ingredients': 'skyblue',
#  'พาสต้านาทูร่าเส้นพาสต้าออร์แกนิคผสมผักโขมและควินัว 250กรัม': 'yellow',
#  'Pasta&Spaghetti': 'skyblue',
#  'คาร์ฟูร์ไบโอเส้นพาสต้ารูปสัตว์ 500กรัม': 'yellow',
#  'พาสต้านาทูร่าเส้นพาสต้าออร์แกนิคผสมสาหร่ายสไปรูลิน่า 250กรัม': 'yellow',
#  'ซันเรโมออร์แกนิกเพนเน่ 500กรัม': 'yellow',
#  'อัลเซเนโร่ออร์แกนิคเพนเน่ 250กรัม': 'yellow',
#  'ดัลลาคอสต้าพาสต้าผสมมะเขือเทศและผักโขมรูปรถ 300กรัม': 'yellow',
#  'ซานรีโมออร์แกนิกสปาเก็ตตี้ 500กรัม': 'yellow',
#  'มายช้อยส์ฟูซิลี่ถั่ว3สีออร์แกนิค 250กรัม': 'yellow',
#  'พาสต้านาทูร่าเส้นพาสต้าออร์แกนิคผสมขมิ้นและพริกไทย 250กรัม': 'yellow',
#  'มายช้อยส์ริกาโทนีถั่วเลนทิลออร์แกนิค 250กรัม': 'yellow',
#  'แฟร์ดีสปาเก็ตตี้ข้าวกล้องหอมมะลิออร์แกนิค 250กรัม': 'yellow',
#  'อัลเซเนโรเส้นพาสต้าออร์แกนิครูปเกลียว 250กรัม': 'yellow',
#  'อัลเซเนโรเส้นพาสต้าออร์แกนิค 250กรัม': 'yellow',
#  'มายช้อยส์ฟูซิลี่ข้าวกล้องออร์แกนิค 250กรัม': 'yellow',
#  'อัลเซเนโร่ออร์แกนิคสปาเก็ตตี้ดูรั่ม 500กรัม': 'yellow',
#  'มายช้อยส์ฟูซิลี่ข้าวสีนิลออร์แกนิค 250กรัม': 'yellow',
#  'อัลเซเนโร่ออร์แกนิคเพนเน่โฮลวีล 250กรัม': 'yellow',
#  'มายช้อยส์ฟูซิลี่ถั่วเขียวออร์แกนิค 250กรัม': 'yellow',
#  'คาร์ฟูร์ไบโอโคควิลเลตเส้นพาสต้า 500กรัม': 'yellow',
#  'อัลเซเนโร่ออร์แกนิคฟูซิลี่ทริคัลเลอร์ 250กรัม': 'yellow',
#  'โคลส์เนยถั่วลิสงชนิดบดละเอียด 500กรัม': 'yellow',
#  'PeanutButter': 'skyblue',
#  'โคลส์เนยถั่วลิสงชนิดบดหยาบ 500กรัม': 'yellow',
#  'โคลส์เนยถั่วออร์แกนิคชนิดบดละเอียด 375กรัม': 'yellow',
#  'โคลส์เนยถั่วออร์แกนิคชนิดบดหยาบ 375กรัม': 'yellow',
#  'แดรี่โฮมนมสดไขมันต่ำ 200ซีซี': 'yellow',
#  'PlainMilk': 'skyblue',
#  'แดรี่โฮมนมสดกราสเฟด 200ซีซี': 'yellow',
#  'บัตเตอร์ฟลายโยเกิร์ตรสธรรมชาติ  100กรัม': 'yellow',
#  'PlainYogurt': 'skyblue',
#  'ปิคนิคมันฝรั่งแท่งทอดกรอบ 106กรัม': 'yellow',
#  'PotatoChips': 'skyblue',
#  'โซลิโต้กาแฟคั่วบดออร์แกนิคโค 250กรัม': 'yellow',
#  'Roast&GroundCoffee': 'skyblue',
#  'แม็คคอร์มิคออร์แกนิคพริกไทยดำบดหยาบ 45กรัม': 'yellow',
#  'Salt,Pepper&ChilliPowder': 'skyblue',
#  'มาล์ดอนเกลือบริโภคชนิดเกล็ด 250กรัม': 'yellow',
#  'เวียดเปปเปอร์พริกไทยดำออร์แกนิคชนิดเม็ด 55กรัม': 'yellow',
#  'เด็กสมบูรณ์ซีอิ๊วขาวออร์แกนิค 300มล.': 'yellow',
#  'Seasoning&DippingSauce': 'skyblue',
#  'เด็กสมบูรณ์ซอสปรุงรสออร์แกนิค 300มล.': 'yellow',
#  'มาสเซิ่ลออแกนิคน้ำซุปรสไก่สำเร็จรูปสูตรลดปริมาณเกลือ 1ลิตร': 'yellow',
#  'Soup&Stock': 'skyblue',
#  'มาสเซิ่ลออแกนิคซุปผักกึ่งสำเร็จรูป 1ลิตร': 'yellow',
#  'ซองเดอร์งาดำคั่วบดออร์แกนิค 100กรัม': 'yellow',
#  'Soy&CerealBeverages': 'skyblue',
#  'อัลเซเนโร่ซอสมะเขือเทศออร์แกนิคอาร์ราเบียต้า 200กรัม': 'yellow',
#  'SpaghettiSauce': 'skyblue',
#  'อัลเซเนโร่ออร์แกนิคซอสเบซิลโทเมโท้ 350กรัม': 'yellow',
#  'อัลเซเนโร่ออร์แกนิควีเจทเทเบิ้ลโทเมโท้ซอส 350กรัม': 'yellow',
#  'อัลเซเนโร่ออร์แกนิคโทเมโท้ซอสวิทพอร์ชินี่มัชรูม 200กรัม': 'yellow',
#  'สเปกตรัมน้ำมันคาโนลาธรรมชาติ 473มล.': 'yellow',
#  'SpecialtyOils': 'skyblue',
#  'โอลิวาโดน้ำมันอโวคาโดเอ็กซ์ตร้าเวอร์จิ้น 250มล.': 'yellow',
#  'นูทรีริสควินัวผสมข้าวไรซ์เบอร์รีออร์แกนิค 750กรัม': 'yellow',
#  'SpecialtyRice': 'skyblue',
#  'แม็คคอร์มิคออร์แกนิคขิงบดละเอียด 35กรัม': 'yellow',
#  'Spices': 'skyblue',
#  'แม็คคอร์มิคออร์แกนิคปาปริก้าป่น 45กรัม': 'yellow',
#  'แม็คคอร์มิคออร์แกนิคเครื่องเทศอิตาเลี่ยน 15กรัม': 'yellow',
#  'แม็คคอร์มิคออร์แกนิคใบไทม์ 18กรัม': 'yellow',
#  'แม็คคอร์มิคออร์แกนิคผงกะหรี่ 49กรัม': 'yellow',
#  'อิโตเอ็นชาเขียวมัทฉะชนิดซอง 18กรัม': 'yellow',
#  'TeaBag': 'skyblue',
#  'ระมิงค์ใบชาเขียวออร์แกนิค 70กรัม': 'yellow',
#  'TeaLeaves': 'skyblue',
#  'โคลส์เมล็ดโกโก้ 200กรัม': 'yellow',
#  'Toppings&Others': 'skyblue',
#  'โปรฟิทเครื่องดื่มธัญญาหารน้ำลูกเดือยไม่เติมน้ำตาล 250มล. แพค 6': 'yellow',
#  'UHTDairyFree': 'skyblue',
#  'โทฟุซังนมถั่วเหลืองออร์แกนิครสออริจินอล 180มล. แพค 4': 'yellow',
#  'โทฟุซังนมถั่วเหลืองออร์แกนิคสูตรหวานน้อย 230มล. แพค 3': 'yellow',
#  'โทฟุซังนมถั่วเหลืองออร์แกนิครสออริจินอล 230มล. แพค 3': 'yellow',
#  'เพียวฮาร์เวสต์ออสซี่ดรีมน้ำนมข้าวกล้องออร์แกนิคเสริมแคลเซี่ยม 1ลิตร': 'yellow',
#  'บอนซอยนมถั่วเหลืองออร์แกนิคขนาด 1ลิตร': 'yellow',
#  'ดีน่าโทนิวน้ำเต้าหู้ออร์แกนิค 180มล.แพค4': 'yellow'}

# %%
G = nx.Graph(graph_data)
G

# %%
# plt.figure(figsize=(16,8))
# nx.draw_kamada_kawai(G, node_size=100)
# plt.show()

# %%
# plt.figure(figsize=(16,8))
# nx.draw_spring(G, node_size=100)
# plt.show()

# %% [markdown]
# ### visualize raw data

# %%
title = "News and NameEntities"
HOVER_TOOLTIPS = [("Character", "@index")]
nx.set_node_attributes(G, node_colors, 'node_colors')
plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
 )

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(size=15, fill_color='node_colors')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
#   <div class="bk-root" id="5bddaa13-d113-43d4-ac76-18c9ef3a56c0" data-root-id="1006"></div>

# %% [markdown]
# ### Compute betweenness_centrality graph

# %%
def cal_size(val, k=10, k2=1000):
    val = val * k * k2
    if val > k: 
        return val
    return k

# %%
graph_values = nx.centrality.betweenness.betweenness_centrality(G)
node_size = {k:cal_size(v, k=10, k2=1000) for k,v in graph_values.items()}

# %%
title = "betweenness_centrality"
HOVER_TOOLTIPS = [("Character", "@index")]

nx.set_node_attributes(G, node_size, 'node_size')
nx.set_node_attributes(G, node_colors, 'node_colors')

plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
)

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(fill_color='node_colors', size='node_size')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
#   <div class="bk-root" id="1d1d5708-83c7-4b96-86a3-60faa241b9af" data-root-id="1194"></div>

# %% [markdown]
# ### compute eigenvector_centrality

# %%
graph_values = nx.centrality.eigenvector.eigenvector_centrality(G, max_iter=600)
node_size = {k:cal_size(v, k=10, k2=15) for k,v in graph_values.items()}

# %%
title = "xxx"
HOVER_TOOLTIPS = [("Character", "@index")]

nx.set_node_attributes(G, node_size, 'node_size') 
nx.set_node_attributes(G, node_colors, 'node_colors')

plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
)

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(fill_color='node_colors', size='node_size')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
#   <div class="bk-root" id="fcfaa844-e115-46fc-8b94-bb987e326af4" data-root-id="1403"></div>
